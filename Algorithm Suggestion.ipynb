# %%
from tkinter import*
from GUI_2 import Customer
class firstpage:
        def __init__(self,root):
            self.root=root
            self.root.title("DSA Library by ZA Developers")
            self.root.geometry("1250x640+10+10")
            self.root.config(background="powder blue")
            
            
            ABC = Frame(self.root, bg="teal", bd=10, relief=GROOVE)
            ABC.grid()
            
            ABCD = Frame(self.root, bg="black", bd=0, relief=GROOVE)
            ABCD.grid(padx=10, pady=20)
            
            ABC1 = Frame(ABC,bd=20, width=1229,height=400,padx=100,bg="teal", relief=GROOVE)
            ABC1.grid(row=0,column=0, columnspan=4, sticky=W)
            
            ABC2 = Frame(ABCD,bd=20, width=1229,height=400,padx=0,pady=0,bg="teal", relief=GROOVE)
            ABC2.grid(row=0,column=0, columnspan=1, sticky=W,pady=0)
            
            ABC5 = LabelFrame(ABC2,bd=15, width=1150,height=340,padx=0,font=("Courier", 20, 'bold',"roman"),text="\t\t⭐Welcome to DSA Library Documentation⭐", bg="teal",fg="white", relief=FLAT)
            ABC5.grid(row=0,column=0, columnspan=5,  sticky=NW,pady=0)
            
            self.lblcopyright = Label(ABC2, text="⭕ With the help of this library you can use any Data Structure functionality without Coding from scratch\n\n⭕ The thing you have to do is to simply call the object of function that we had defined in this library\nand you will get the output\n\n⭕ This Python data structure library help in reducing coding errors, make programmers more efficient\nand make code smaller in size\n\n⭕ This library contains mostly used methods or functions of Data structures.Names and uses of those \nmethods are explained in detail in hand book of this module\n\n⭕ Please read the hand book before using this library to understand the functionality and work\nefficienly by taking full advantage of this module\n\n⭕ Here you can also find the best data structure for your problem by answering few simple questions.", font=("Courier", 14,"roman") ,justify= LEFT,padx=0,pady=0,bd=5,bg="teal",fg="white").grid(row=0,column=0,sticky=NW,pady=35)


            
            self.lblTitle = Label(ABC1,text="\tDSA Library By ZA Developers \t", font=("Courier", 22, 'bold',"roman"),pady=10,bd=4,width=58,bg="teal",fg="Cornsilk",justify= CENTER).grid(row=0,column=1)
            
            def questions():
                    root.destroy()
                    
                    class secondpage:
                            def __init__(self,root1):
                                self.root1=root1
                                self.root1.title("DSA Library by ZA Developers")
                                self.root1.geometry("1250x640+10+10")
                                self.root1.config(background="powder blue")



                                ABC = Frame(self.root1, bg="teal", bd=10, relief=GROOVE)
                                ABC.grid()

                                ABCD = Frame(self.root1, bg="black", bd=0, relief=GROOVE)
                                ABCD.grid(padx=10, pady=20)

                                ABC1 = Frame(ABC,bd=20, width=1229,height=400,padx=100,bg="teal", relief=GROOVE)
                                ABC1.grid(row=0,column=0, columnspan=4, sticky=W)

                                ABC2 = Frame(ABCD,bd=20, width=1229,height=400,padx=0,pady=0,bg="teal", relief=GROOVE)
                                ABC2.grid(row=0,column=0, columnspan=1, sticky=W,pady=0)

                                ABC5 = LabelFrame(ABC2,bd=15, width=1150,height=450,padx=0,font=("Courier", 15, 'bold',"roman"),text="\t   Please answer the following Questions for data structure suggestion", bg="teal",fg="white", relief=FLAT)
                                ABC5.grid(row=0,column=0, columnspan=5,  sticky=NW,pady=0)

                                Q1 = StringVar()
                                Q2 = StringVar()
                                Q3 = StringVar()
                                Q4 = StringVar()
                                Q5 = StringVar()
                                Q6 = StringVar()
                                Q7 = StringVar()
                                Q8 = StringVar()
                                Q9 = StringVar()
                                Q10 = StringVar()
                                output=StringVar()


                                self.lblQ1 = Label(ABC5, text="Is the relationship between your data hierarchical?  ", font=("Ariel",15,"bold"),bg="teal",fg="white").grid(row=1,column=0,sticky=W,pady=9)
                                self.txtQ1 = Entry(ABC5,font=("Ariel",12,"bold"),textvariable=Q1,width=12).grid(row=1,column=1,pady=9)

                    #             self.lblQ2 = Label(ABC5, text="Biryani Rs 150       ", font=("Ariel",15,"bold"),bg="teal",fg="Cornsilk").grid(row=2,column=0,sticky=W,pady=3)
                    #             self.txtQ2 = Entry(ABC5,font=("Ariel",12,"bold"),textvariable=Q2,width=12).grid(row=2,column=12,pady=3)

                                self.lblQ3 = Label(ABC5, text="Do you want back tracking?    ", font=("Ariel",15,"bold"),bg="teal",fg="white").grid(row=2,column=0,sticky=W,pady=9)
                                self.txtQ3 = Entry(ABC5,font=("Ariel",12,"bold"),textvariable=Q3,width=12).grid(row=2,column=1,pady=9)

                                self.lblQ4 = Label(ABC5, text="Does your code contain the evaluation of expression?", font=("Ariel",15,"bold"),bg="teal",fg="white").grid(row=4,column=0,sticky=W,pady=9)
                                self.txtQ4 = Entry(ABC5,font=("Ariel",12,"bold"),textvariable=Q4,width=12).grid(row=4,column=1,pady=9)

                                self.lblQ5 = Label(ABC5, text="Are you dealing with an unknown number of objects or don’t know how many items are in the list? ", font=("Ariel",15,"bold"),bg="teal",fg="white").grid(row=5,column=0,sticky=W,pady=9)
                                self.txtQ5 = Entry(ABC5,font=("Ariel",12,"bold"),textvariable=Q5,width=12).grid(row=5,column=1,pady=9)

                                self.lblQ6 = Label(ABC5, text="Is the order of your data important? ", font=("Ariel",15,"bold"),bg="teal",fg="white").grid(row=6,column=0,sticky=W,pady=9)
                                self.txtQ6 = Entry(ABC5,font=("Ariel",12,"bold"),textvariable=Q6,width=12).grid(row=6,column=1,pady=9)

                                self.lblQ7 = Label(ABC5, text= "Is your data dependent on one another?  ", font=("Ariel",15,"bold"),bg="teal",fg="white").grid(row=7,column=0,sticky=W,pady=9)
                                self.txtQ7 = Entry(ABC5,font=("Ariel",12,"bold"),textvariable=Q7,width=12).grid(row=7,column=1,pady=9)

                    #             self.lblQ8 = Label(ABC5, text="    ", font=("Ariel",15,"bold"),bg="teal",fg="white").grid(row=8,column=0,sticky=W,pady=3)
                    #             self.txtQ8 = Entry(ABC5,font=("Ariel",12,"bold"),textvariable=Q8,width=12).grid(row=8,column=1,pady=3)

                    #             self.lblQ9 = Label(ABC5, text=" ", font=("Ariel",15,"bold"),bg="teal",fg="white").grid(row=9,column=0,sticky=W,pady=3)
                    #             self.txtQ9 = Entry(ABC5,font=("Ariel",12,"bold"),textvariable=Q9,width=12).grid(row=9,column=1,pady=3)

                    #             self.lblQ10 = Label(ABC5, text="   ", font=("Ariel",15,"bold"),bg="teal",fg="white").grid(row=10,column=0,sticky=W,pady=3)
                    #             self.txtQ10 = Entry(ABC5,font=("Ariel",12,"bold"),textvariable=Q10,width=12).grid(row=10,column=1,pady=3)


                                self.lblTitle = Label(ABC1,text="\tDSA Library By ZA Developers \t", font=("Courier", 22, 'bold',"roman"),pady=10,bd=4,width=58,bg="teal",fg="Cornsilk",justify= CENTER).grid(row=0,column=1)

                                self.lbloutput = Label(ABC5, text="Suggestion:", font=("Ariel",18,"bold"),padx=2,bd=5,bg="teal",fg="white").grid(row=11,column=0,sticky=W,padx=0,pady=13)
                                self.txtoutput = Entry(ABC5,font=("Ariel",12,"bold"),textvariable=output,width=20).grid(row=11,column=1,padx=0,pady=13,sticky=N)


                                class A:
                                    def a():
                                        
                                        try:q1 = str(Q1.get())    
                                        except:q1=0
                                        try:q3 = str(Q3.get())    
                                        except:q3=0
                                        try:q4 = str(Q4.get())    
                                        except:q4=0
                                        try:q5 = str(Q5.get())    
                                        except:q5=0
                                        try:q6 = str(Q6.get())    
                                        except:q6=0
                                        try:q7 = str(Q7.get())    
                                        except:q7=0
                    #                     try:q8 = str(Q8.get())    
                    #                     except:q8=0
                    #                     try:q9 = str(Q9.get())    
                    #                     except:q9=0
                    #                     try:q10 = str(Q10.get())    
                    #                     except:q10=0

                                        stack=0
                                        linkedlist=0
                                        queue=0
                                        BST=0
                                        List=0

                                        if q1=="yes":
                                            BST+=3
                                        if q1=="no":
                                            linkedlist+=1
                                            stack+=1
                                            queue+=1
                                            List+=1
                                        if q3=="yes":
                                            stack+=1
                                        if q4=="yes":
                                            stack+=1
                                            BST+=1
                                        if q5=="yes":
                                            linkedlist+=1 
                                        if q6=="yes":
                                            stack+=1
                                            queue+=1
                                        if q7=="yes":
                                            linkedlist+=1
                                        if q7=="no":
                                            List+=1
                    #                     if q8=="no":
                    #                         List+=1

                                        l=[]
                                        l.append(stack)
                                        l.append(linkedlist)
                                        l.append(queue)
                                        l.append(BST)
                                        l.append(List)
                                        print(l)
                                        l.sort(reverse=True)
                                        print(l)




                                        if l[0]== stack:
                                            print("stack")
                                            x='stack'

                                        elif l[0]== linkedlist:
                                            print("linkedlist")
                                            x='linkedlist'

                                        elif l[0]== queue:
                                            print("queue")
                                            x='Queue'

                                        elif l[0]== BST:
                                            print("BST")
                                            x='Tree'

                                        else:
                                            pass

                                        if l[1]== linkedlist:
                                            print("linkedlist")
                                            y='linkedlist'    


                                        elif l[1]== stack:
                                            print("stack")
                                            y='stack'


                                        elif l[1]== queue:
                                            print("queue")
                                            y='Queue'

                                        elif l[1]== BST:
                                            print("BST")
                                            y='Tree'



                                        else:
                                            pass

                                        if x==y:
                                            output.set(x)
                                        else:
                                            X=x+" or "+y
                                            print(X)
                                            output.set(X)



                                    self.btn1 = Button(ABC2,padx=0, pady=5, bd=5,fg="black",font=("Ariel",11,'bold'),width=50,height=1,bg="white",text="NEXT",command=a).grid(row=2,column=0,padx=365,pady=0)

                                obj=A()


                    if __name__=='__main__':
                                root1=Tk()
                                application = secondpage(root1)                 
                                root1.mainloop()
                                
                                
            self.btn1 = Button(ABC2,padx=0, pady=5, bd=5,fg="black",font=("Ariel",11,'bold'),width=50,height=1,bg="white",text="Click Here to get the best data stucture for your problem",command=questions).grid(row=2,column=0,padx=365,pady=0)


            

            

            


            


if __name__=='__main__':
            root=Tk()
            application = firstpage(root)
#             app2 = firstpage(root)                   
            root.mainloop()
# Out:
# [0, 2, 0, 3, 0]
# [3, 2, 0, 0, 0]
# BST
# linkedlist
# Tree or linkedlist
# [2, 3, 2, 0, 1]
# [3, 2, 2, 1, 0]
# linkedlist
# stack
# linkedlist or stack
